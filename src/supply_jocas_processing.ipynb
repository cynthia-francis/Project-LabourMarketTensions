# %% [markdown]
# ## MERGING JOCAS (JOB SUPPLY) DATA

# %% [markdown]
# The JOCAS data available to us from Progedo (2020) is composed as follow:
#
# ```plaintext
# JOCAS/
# │── Website_1/
# │   ├── January/
# │   │   ├── 01.xlsx
# │   │   ├── 02.xlsx
# │   │   ├── ...
# │   │   ├── 31.xlsx
# │   ├── ...
# │   ├── December/
# │   │   ├── 01.xlsx
# │   │   ├── 02.xlsx
# │   │   ├── ...
# │   │   ├── 31.xlsx
# │
# │── Website_2/
# │   ├── January/
# │   │   ├── 01.xlsx
# │   │   ├── 02.xlsx
# │   │   ├── ...
# │   │   ├── 31.xlsx
# │   ├── ...
# │
# │── ...
# ```
# The objective of this notebook is to extract the data of interest from all this JOCAS database (data for communes>5000 habitants) into one excel file

# %%
# IMPORT LIBRARIES
import matplotlib.pyplot as plt
import pandas as pd
import os
import re # For regular expression
import geopandas as gpd # To read geospatial data
from pathlib import Path # To set relative paths
import unidecode # To standardize strings
import py7zr # To unzip files

# %%
# GETTING PROJECT'S ROOT DIRECTORY
base_folder = Path().resolve()  # CURRENT WORKING DIRECTORY
main_folder = base_folder.parent

# JOCAS DIRECTORY 
jocas_dir = ""

# IMPORTING FILES
commune_names_path = main_folder / "data" / "2- Formatted Data" / "name_communes_5000.csv"
commune_names = pd.read_csv(commune_names_path).squeeze().tolist()  
rome_fap_path = main_folder / "data" / "linking tables" / "Rome_to_Fap_processed.csv"
rome_fap = pd.read_csv(rome_fap_path)

# %%
# READ DATASET
df = pd.read_csv("/Users/alfonso/Desktop/JOCAS DATA/leboncoin/2020-01/20200101_offers.csv", sep=";")

# RENAME COLUMNS OF INTEREST
df.rename(columns={"location_label": "commune", "job_ROME_code": "rome_code"}, inplace=True)

# COMMUNE NAME STANDARDIZATION FUNCTION
def standardize_commune(name):
    if pd.isna(name):
        return None
    name = unidecode.unidecode(name.lower().strip())  # Remove accents & lowercase
    name = re.sub(r"[-'’]", " ", name)  # Remove hyphens & apostrophes
    name = re.sub(r"\bst[ .]", "saint ", name)  # Standardize "St." -> "Saint"
    return name

# APPLY STANDARDIZATION
df["commune"] = df["commune"].apply(standardize_commune)

# FILTER FOR COMMUNES WITH MORE THAN 5000 HABITANTS
df_filtered = df[df["commune"].isin(commune_names)]

# MERGE ROME CODE WITH LINKING TABLE (TO FAP)
df_grouped = df_grouped.merge(rome_fap, left_on="rome_code", right_on="ROME", how="left")

# GROUP BY COMMUNE AND CODE ROME AND COUNT JOB OFFERS
df_grouped = df_grouped.groupby(["commune", "fap225"]).size().reset_index(name="job_offers_fap225")

# %%
# Out:
#                 commune fap225  job_offers_fap225
# 0                  agen  B3Z20                  4
# 1                  agen  B4Z41                  4
# 2       aire sur la lys  B0Z20                  1
# 3       aix en provence  D3Z20                  4
# 4       aix en provence  D4Z41                  4
# 5       aix en provence  J0Z20                  9
# 6       aix en provence  J1Z40                  9
# 7       aix en provence  J1Z80                  9
# 8         aix les bains  J0Z20                  4
# 9         aix les bains  J1Z40                  4
# 10          albertville  L6Z00                  1
# 11              alencon  B3Z20                  4
# 12              alencon  B4Z43                  4
# 13              alencon  D3Z20                  9
# 14              alencon  G0B41                  9
# 15              alencon  G1Z70                  9
# 16                 ales  D3Z20                  9
# 17                 ales  E0Z21                  4
# 18                 ales  E1Z42                  4
# 19                 ales  G0B41                  9
# 20                 ales  G1Z70                  9
# 21                 ales  T4Z60                  1
# 22               amiens  R2Z80                  1
# 23  andrezieux boutheon  E0Z21                  4
# 24  andrezieux boutheon  E1Z42                  4
# 25  andrezieux boutheon  J0Z20                  4
# 26  andrezieux boutheon  J1Z40                  4
# 27               angers  W0Z90                  1
# 28               anglet  L5Z90                  1
# 29            angouleme  D2Z42                  4
# 30            angouleme  D3Z20                  4
# 31               antony  L2Z61                  4
# 32               antony  L4Z80                  4
# 33               antony  T2B60                  1
# 34                  apt  J0Z20                  4
# 35                  apt  J1Z40                  4
# 36             argentan  Q1Z80                  4
# 37             argentan  Q2Z90                  4
# 38           argenteuil  L0Z60                  4
# 39           argenteuil  L3Z80                  4

# %%
rome_fap.head(5)
# Out:
#   fap22               famille_pro22 fap87  \
# 0     A  Agriculture, marine, pêche   A0Z
# 1     A  Agriculture, marine, pêche   A0Z
# 2     A  Agriculture, marine, pêche   A0Z
# 3     A  Agriculture, marine, pêche   A0Z
# 4     A  Agriculture, marine, pêche   A0Z
#
#                                       famille_pro87 fap225  \
# 0  Agriculteurs, éleveurs, sylviculteurs, bûcherons  A0Z00
# 1  Agriculteurs, éleveurs, sylviculteurs, bûcherons  A0Z01
# 2  Agriculteurs, éleveurs, sylviculteurs, bûcherons  A0Z02
# 3  Agriculteurs, éleveurs, sylviculteurs, bûcherons  A0Z40
# 4  Agriculteurs, éleveurs, sylviculteurs, bûcherons  A0Z41
#
#                           famille_pro225   PCS  \
# 0              Agriculteurs indépendants  111a
# 1                  Éleveurs indépendants  111d
# 2  Bûcherons, sylviculteurs indépendants  122b
# 3                  Agriculteurs salariés  691e
# 4                      Éleveurs salariés  691b
#
#      Professions et catégories socioprofessionnelles   ROME  \
# 0  Agriculteurs sur petite exploitation de céréal...    NaN
# 1     Éleveurs d'herbivores, sur petite exploitation    NaN
# 2  Exploitants forestiers indépendants, de 0 à 9 ...    NaN
# 3  Ouvriers agricoles sans spécialisation particu...  A1416
# 4                              Ouvriers de l'élevage  A1403
#
#   Répertoire Opérationnel des Métiers et des Emplois
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                               Polyculture, élevage
# 4                Aide d'élevage agricole et aquacole
