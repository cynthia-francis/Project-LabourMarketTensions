# %% [markdown]
# # 💼 Title: Merging DARES tension indicators with Departements Geospatial  Data

# %% [markdown]
# 📌 Overview
# This notebook merges DARES labor market tension indicators for professions (FAP 87 and FAP 225) at the department level with geospatial department data.

# %%
# IMPORT LIBRARIES
import matplotlib.pyplot as plt
import pandas as pd
import re # For regular expression
import geopandas as gpd # To read geospatial data
from pathlib import Path # To set relative paths
import unidecode # To standardize strings
import numpy as np

# %%
# GETTING PROJECT'S ROOT DIRECTORY
base_folder = Path().resolve()  # CURRENT WORKING DIRECTORY
main_folder = base_folder.parent

# %%
# SETTING ALL NECESSARY DIRECTORIES
shapefile_path = main_folder / "data" / "shapefiles" / "Departements" / "departements-20180101.shp"

# Please change here the path after uploading the excel to github
indicators_path = main_folder / "data" / "1- Raw Data" / "DARES TENSIONS INDICATORS" / "Dares_données_tensions_2022_.xlsx"

# Set output path
output_path = main_folder / "data" / "2- Formatted Data" / "matched_dares_indicators_departements.csv"

# %%
# IMPORTING FILES
departements_shp = gpd.read_file(shapefile_path)
indicators_fap87_df = pd.read_excel(indicators_path, sheet_name="FAP 87 x DEP")
indicators_fap225_df = pd.read_excel(indicators_path, sheet_name="FAP 225 x DEP")

# %%
# EXPLORING GEO FILE AND SMALL ADJUSTMENTS
departements_shp.rename(columns={"nom": "departement"}, inplace=True)
departements_shp.head()
# Out:
#   code_insee       departement  nuts3              wikipedia  surf_km2  \
# 0        974        La Réunion  FR940          fr:La Réunion    2505.0
# 1         11              Aude  FR811  fr:Aude (département)    6343.0
# 2         43       Haute-Loire  FR723         fr:Haute-Loire    5003.0
# 3         13  Bouches-du-Rhône  FR823    fr:Bouches-du-Rhône    5247.0
# 4         47    Lot-et-Garonne  FR614      fr:Lot-et-Garonne    5385.0
#
#                                             geometry
# 0  MULTIPOLYGON (((55.216 -21.039, 55.217 -21.039...
# 1  POLYGON ((1.6887 43.274, 1.69 43.274, 1.6921 4...
# 2  POLYGON ((3.0821 45.29, 3.0821 45.29, 3.0823 4...
# 3  MULTIPOLYGON (((4.2301 43.46, 4.2302 43.461, 4...
# 4  POLYGON ((-0.14058 44.226, -0.12931 44.232, -0...

# %%
# EXPLORING INDICATORS FILES AND SMALL ADJUSTMENTS
indicators_fap87_df.rename(columns={"Libellé département": "departement_nom"}, inplace=True)
indicators_fap87_df.head()
indicators_fap225_df.rename(columns={"Libellé département": "departement_nom"}, inplace=True)
indicators_fap225_df.head()
# Out:
#    Année Code FAP 225        Libellé FAP 225 Code département  \
# 0   2011        A0Z40  Agriculteurs salariés               01
# 1   2011        A0Z40  Agriculteurs salariés               02
# 2   2011        A0Z40  Agriculteurs salariés               03
# 3   2011        A0Z40  Agriculteurs salariés               04
# 4   2011        A0Z40  Agriculteurs salariés               05
#
#            departement_nom  Emploi moyen (2015-2019)   Tension  \
# 0                      AIN                458.314320      n.d.
# 1                    AISNE               1263.645583 -0.578154
# 2                   ALLIER                459.747956  -0.89294
# 3  ALPES-DE-HAUTE-PROVENCE                330.000757  0.168244
# 4             HAUTES-ALPES                238.756790      n.d.
#
#    Tension (Valeurs imputées: volumétrie insuffisantes) Intensité d'embauches  \
# 0                                           0.479026                     n.d.
# 1                                          -0.578154                 0.707496
# 2                                          -0.892940                 0.721193
# 3                                           0.168244                  7.86582
# 4                                          -0.237149                     n.d.
#
#   Lien formation-emploi  ... Conditions de travail contraignantes  \
# 0                  n.d.  ...                                 n.d.
# 1             -0.199432  ...                             0.436598
# 2             -0.199432  ...                             0.436598
# 3             -0.199432  ...                             0.436598
# 4                  n.d.  ...                                 n.d.
#
#   Inadéquation géographique Tension - discret Intensité d'embauches - discret  \
# 0                      n.d.              n.d.                            n.d.
# 1                  1.098667                 2                               5
# 2                  1.098667                 1                               5
# 3                  1.098667                 4                               5
# 4                      n.d.              n.d.                            n.d.
#
#   Lien formation-emploi - discret  \
# 0                            n.d.
# 1                               3
# 2                               3
# 3                               3
# 4                            n.d.
#
#   Manque de main d'oeuvre disponible - discret  \
# 0                                         n.d.
# 1                                            4
# 2                                            3
# 3                                            3
# 4                                         n.d.
#
#   Non-durabilité de l'emploi - discret  \
# 0                                 n.d.
# 1                                    5
# 2                                    5
# 3                                    5
# 4                                 n.d.
#
#   Conditions de travail contraignantes - discret  \
# 0                                           n.d.
# 1                                              4
# 2                                              4
# 3                                              4
# 4                                           n.d.
#
#   Inadéquation géographique - discret Croisement où volumétrie suffisante
# 0                                n.d.                          FAP87 - DEP
# 1                                   5                         FAP225 - DEP
# 2                                   5                         FAP225 - DEP
# 3                                   5                         FAP225 - DEP
# 4                                n.d.                          FAP87 - DEP
#
# [5 rows x 22 columns]

# %% [markdown]
# # The objective is to match our "departement_nom" columns in each indicator dataframe (fap87 and fap225) with the "departement" column to align geospatial information for future mapping.

# %% [markdown]
# 1- STANDARDIZATION OF DEPARTEMENTS COLUMN FROM ALL DATASETS

# %%
# Standardization function for department names
def standardize_dep(name):
    if pd.isna(name):  # Handle missing values
        return None
    name = unidecode.unidecode(name.lower().strip())  # Remove accents, lowercase, and strip whitespace
    name = re.sub(r"[-'’]", " ", name)  # Replace hyphens and apostrophes with spaces
    name = re.sub(r"\bst[ .]", "saint ", name)  # Standardize "St." or "St-" to "Saint"
    name = re.sub(r"\s+", " ", name)  # Replace multiple spaces with a single space
    return name

# Apply standardization
indicators_fap87_df["departement_nom"] = indicators_fap87_df["departement_nom"].apply(standardize_dep)
indicators_fap225_df["departement_nom"] = indicators_fap225_df["departement_nom"].apply(standardize_dep)
departements_shp["departement"] = departements_shp["departement"].apply(standardize_dep)

# %% [markdown]
# 2- MERGE DATASETS

# %%
# Merge datasets
indicators_fap87_df_merged = indicators_fap225_df.merge(departements_shp, left_on="departement_nom", right_on="departement", how="left")
indicators_fap87_df_merged.head(5)

indicators_fap225_df_merged = indicators_fap225_df.merge(departements_shp, left_on="departement_nom", right_on="departement", how="left")
indicators_fap225_df_merged.head(5)
# Out:
#    Année Code FAP 225        Libellé FAP 225 Code département  \
# 0   2011        A0Z40  Agriculteurs salariés               01
# 1   2011        A0Z40  Agriculteurs salariés               02
# 2   2011        A0Z40  Agriculteurs salariés               03
# 3   2011        A0Z40  Agriculteurs salariés               04
# 4   2011        A0Z40  Agriculteurs salariés               05
#
#            departement_nom  Emploi moyen (2015-2019)   Tension  \
# 0                      ain                458.314320      n.d.
# 1                    aisne               1263.645583 -0.578154
# 2                   allier                459.747956  -0.89294
# 3  alpes de haute provence                330.000757  0.168244
# 4             hautes alpes                238.756790      n.d.
#
#    Tension (Valeurs imputées: volumétrie insuffisantes) Intensité d'embauches  \
# 0                                           0.479026                     n.d.
# 1                                          -0.578154                 0.707496
# 2                                          -0.892940                 0.721193
# 3                                           0.168244                  7.86582
# 4                                          -0.237149                     n.d.
#
#   Lien formation-emploi  ... Non-durabilité de l'emploi - discret  \
# 0                  n.d.  ...                                 n.d.
# 1             -0.199432  ...                                    5
# 2             -0.199432  ...                                    5
# 3             -0.199432  ...                                    5
# 4                  n.d.  ...                                 n.d.
#
#   Conditions de travail contraignantes - discret  \
# 0                                           n.d.
# 1                                              4
# 2                                              4
# 3                                              4
# 4                                           n.d.
#
#   Inadéquation géographique - discret Croisement où volumétrie suffisante   \
# 0                                n.d.                          FAP87 - DEP
# 1                                   5                         FAP225 - DEP
# 2                                   5                         FAP225 - DEP
# 3                                   5                         FAP225 - DEP
# 4                                n.d.                          FAP87 - DEP
#
#   code_insee              departement  nuts3                   wikipedia  \
# 0         01                      ain  FR711        fr:Ain (département)
# 1         02                    aisne  FR221      fr:Aisne (département)
# 2         03                   allier  FR721     fr:Allier (département)
# 3         04  alpes de haute provence  FR821  fr:Alpes-de-Haute-Provence
# 4         05             hautes alpes  FR822             fr:Hautes-Alpes
#
#   surf_km2                                           geometry
# 0   5784.0  POLYGON ((4.7282 45.946, 4.7282 45.948, 4.7287...
# 1   7411.0  POLYGON ((2.958 49.227, 2.958 49.227, 2.9582 4...
# 2   7379.0  POLYGON ((2.2768 46.425, 2.2769 46.425, 2.277 ...
# 3   6993.0  POLYGON ((5.4964 44.103, 5.4973 44.104, 5.4975...
# 4   5697.0  POLYGON ((5.4184 44.425, 5.4185 44.425, 5.4186...
#
# [5 rows x 28 columns]

# %% [markdown]
# 3- WHICH DEPARTEMENTS WERE NOT MATCHED AND WHY?

# %%
# Extract unique unmatched commune names as a list
unique_unmatched_dep_87_list = indicators_fap87_df_merged.loc[indicators_fap87_df_merged["departement"].isna(), "departement_nom"].drop_duplicates().tolist()
unique_unmatched_dep_225_list  = indicators_fap225_df_merged.loc[indicators_fap225_df_merged["departement"].isna(), "departement_nom"].drop_duplicates().tolist()
# Print the list
print(unique_unmatched_dep_87_list)
print(unique_unmatched_dep_225_list)
# Out:
# ['reunion']
# ['reunion']

# %%
# Since only 1 departement was not matched, we will manually map it
manual_mapping = {'reunion': 'la reunion'}

# Apply manual mapping to unmatched names in FAP 87 and FAP 225 datasets
indicators_fap87_df_merged['departement_nom'] = indicators_fap87_df_merged['departement_nom'].replace(manual_mapping)
indicators_fap87_df_merged['departement_nom'] = indicators_fap87_df_merged['departement_nom'].replace(manual_mapping)#

# %%
indicators_fap87_df_merged
# Out:
#         Année Code FAP 225        Libellé FAP 225 Code département  \
# 0        2011        A0Z40  Agriculteurs salariés               01
# 1        2011        A0Z40  Agriculteurs salariés               02
# 2        2011        A0Z40  Agriculteurs salariés               03
# 3        2011        A0Z40  Agriculteurs salariés               04
# 4        2011        A0Z40  Agriculteurs salariés               05
# ...       ...          ...                    ...              ...
# 223195   2022        W1Z80             Formateurs               95
# 223196   2022        W1Z80             Formateurs              971
# 223197   2022        W1Z80             Formateurs              972
# 223198   2022        W1Z80             Formateurs              973
# 223199   2022        W1Z80             Formateurs              974
#
#                 departement_nom  Emploi moyen (2015-2019)   Tension  \
# 0                           ain                458.314320      n.d.
# 1                         aisne               1263.645583 -0.578154
# 2                        allier                459.747956  -0.89294
# 3       alpes de haute provence                330.000757  0.168244
# 4                  hautes alpes                238.756790      n.d.
# ...                         ...                       ...       ...
# 223195               val d oise               1954.470600      n.d.
# 223196               guadeloupe                693.892535 -0.256632
# 223197               martinique                857.978172  0.446474
# 223198                   guyane                565.416529   0.48958
# 223199               la reunion               1656.100510 -0.471774
#
#         Tension (Valeurs imputées: volumétrie insuffisantes)  \
# 0                                                0.479026
# 1                                               -0.578154
# 2                                               -0.892940
# 3                                                0.168244
# 4                                               -0.237149
# ...                                                   ...
# 223195                                           0.861737
# 223196                                          -0.256632
# 223197                                           0.446474
# 223198                                           0.489580
# 223199                                          -0.471774
#
#        Intensité d'embauches Lien formation-emploi  ...  \
# 0                       n.d.                  n.d.  ...
# 1                   0.707496             -0.199432  ...
# 2                   0.721193             -0.199432  ...
# 3                    7.86582             -0.199432  ...
# 4                       n.d.                  n.d.  ...
# ...                      ...                   ...  ...
# 223195                  n.d.                  n.d.  ...
# 223196              1.084922             -1.005707  ...
# 223197             -0.563423             -1.005707  ...
# 223198              0.674707             -1.005707  ...
# 223199              1.351161             -1.005707  ...
#
#        Non-durabilité de l'emploi - discret  \
# 0                                      n.d.
# 1                                         5
# 2                                         5
# 3                                         5
# 4                                      n.d.
# ...                                     ...
# 223195                                 n.d.
# 223196                                    5
# 223197                                    3
# 223198                                    2
# 223199                                    2
#
#        Conditions de travail contraignantes - discret  \
# 0                                                n.d.
# 1                                                   4
# 2                                                   4
# 3                                                   4
# 4                                                n.d.
# ...                                               ...
# 223195                                           n.d.
# 223196                                              1
# 223197                                              1
# 223198                                              1
# 223199                                              1
#
#        Inadéquation géographique - discret  \
# 0                                     n.d.
# 1                                        5
# 2                                        5
# 3                                        5
# 4                                     n.d.
# ...                                    ...
# 223195                                n.d.
# 223196                                   2
# 223197                                   2
# 223198                                   2
# 223199                                   2
#
#        Croisement où volumétrie suffisante  code_insee  \
# 0                               FAP87 - DEP         01
# 1                              FAP225 - DEP         02
# 2                              FAP225 - DEP         03
# 3                              FAP225 - DEP         04
# 4                               FAP87 - DEP         05
# ...                                     ...        ...
# 223195                         FAP225 - REG         95
# 223196                         FAP225 - DEP        971
# 223197                         FAP225 - DEP        972
# 223198                         FAP225 - DEP        973
# 223199                         FAP225 - DEP        NaN
#
#                     departement  nuts3                   wikipedia surf_km2  \
# 0                           ain  FR711        fr:Ain (département)   5784.0
# 1                         aisne  FR221      fr:Aisne (département)   7411.0
# 2                        allier  FR721     fr:Allier (département)   7379.0
# 3       alpes de haute provence  FR821  fr:Alpes-de-Haute-Provence   6993.0
# 4                  hautes alpes  FR822             fr:Hautes-Alpes   5697.0
# ...                         ...    ...                         ...      ...
# 223195               val d oise  FR108               fr:Val-d'Oise   1253.0
# 223196               guadeloupe  FR910               fr:Guadeloupe   1634.0
# 223197               martinique  FR920               fr:Martinique   1089.0
# 223198                   guyane  FR930                   fr:Guyane  83543.0
# 223199                      NaN    NaN                         NaN      NaN
#
#                                                  geometry
# 0       POLYGON ((4.7282 45.946, 4.7282 45.948, 4.7287...
# 1       POLYGON ((2.958 49.227, 2.958 49.227, 2.9582 4...
# 2       POLYGON ((2.2768 46.425, 2.2769 46.425, 2.277 ...
# 3       POLYGON ((5.4964 44.103, 5.4973 44.104, 5.4975...
# 4       POLYGON ((5.4184 44.425, 5.4185 44.425, 5.4186...
# ...                                                   ...
# 223195  POLYGON ((1.609 49.078, 1.6096 49.078, 1.6103 ...
# 223196  MULTIPOLYGON (((-61.81 16.273, -61.81 16.273, ...
# 223197  MULTIPOLYGON (((-61.229 14.822, -61.229 14.822...
# 223198  MULTIPOLYGON (((-54.603 2.3337, -54.603 2.3351...
# 223199                                               None
#
# [223200 rows x 28 columns]

# %%
gdf["Libellé FAP 225"].unique
# Out:
# <bound method Series.unique of 0         Agriculteurs salariés
# 1         Agriculteurs salariés
# 2         Agriculteurs salariés
# 3         Agriculteurs salariés
# 4         Agriculteurs salariés
#                   ...
# 223195               Formateurs
# 223196               Formateurs
# 223197               Formateurs
# 223198               Formateurs
# 223199               Formateurs
# Name: Libellé FAP 225, Length: 223200, dtype: object>

# %% [markdown]
# 4- QUICK VISUALISATION FOR EACH FAP DATAFRAME

# %%
import contextily as ctx
import matplotlib.colors as mcolors

# Reassignment
gdf = indicators_fap225_df_merged

# Filter Conducteurs routiers in 2022
fap = gdf["Libellé FAP 225"] == "Cuisiniers"
year = gdf["Année"] == 2022
columns = ["Tension", "geometry"]

# Select dataset with filters
gdf_map = gdf[fap & year][columns]

# Convert "Tension" to numeric in gdf_map
gdf_map["Tension"] = pd.to_numeric(gdf_map["Tension"].replace("n.d.", np.nan), errors="coerce")

# Convert df_map to GeoDataFrame and filter missing geometries
gdf_map = gpd.GeoDataFrame(gdf_map, geometry="geometry", crs="EPSG:4326")

# Define bounding box for mainland France
xmin, xmax, ymin, ymax = -5, 10, 41, 52

# Keep only geometries within mainland France
gdf_map = gdf_map[gdf_map.geometry.bounds.minx >= xmin]
gdf_map = gdf_map[gdf_map.geometry.bounds.maxx <= xmax]
gdf_map = gdf_map[gdf_map.geometry.bounds.miny >= ymin]
gdf_map = gdf_map[gdf_map.geometry.bounds.maxy <= ymax]

# Create figure
fig, ax = plt.subplots(figsize=(10, 12))

# Plot the map
gdf_map.plot(column="Tension", cmap="Reds", linewidth=0.1, edgecolor="black",
             legend=True, scheme="quantiles", ax=ax)

# Add basemap
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)

# Clean visualization
ax.set_title("Labour Market Tension for Conducteurs Routiers (2022)", fontsize=14)
ax.axis("off")

# Show the plot
plt.show()
# Out:
# /Users/alfonso/anaconda3/lib/python3.11/site-packages/contextily/tile.py:645: UserWarning: The inferred zoom level of 23 is not valid for the current tile provider (valid zooms: 0 - 20).
#   warnings.warn(msg)
